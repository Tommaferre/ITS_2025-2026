# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Docente:** Michele Leone
#
# **Unità Formativa (UF):** Fondamenti di programmazione
#
# **Titolo argomento:** Verifica Intermedia 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **RIEPILOGO REGOLE FONDAMENTALI**:
#
# - Non modificare il testo dell'esercizio
# - Svolgere l'esercizio nel blocco "Codice" sottostante il testo dell'esercizio a cui si riferisce
# - Utilizzare **esclusivamente** le istruzioni che abbiamo visto durante le lezioni
# - Il codice che scriverete dovrà risolvere puntualmente la richiesta.
# - Potete utilizzare il materiale distribuito/creato durante le lezioni
# - **É obbigatorio spiegare, attraverso i commenti, i passaggi chiave degli script**
# - Questo foglio di lavoro andrà caricato nell'apposita sezione della FAD
# ---

# %% [markdown]
# # **Esercizio 1: Elenchi**
#
# - Crea un elenco chiamato fruits contenente i seguenti elementi:
#   - "mela"
#   - "banana"
#   - "ciliegia"
# - Aggiungi l'elemento "arancia" all'elenco
# - Rimuovi l'elemento "banana" dall'elenco
# - Stampa l'elenco risultante

# %% [markdown]
# #**Esercizio 2: Dizionari**
#
# - Crea un dizionario chiamato fruits_dict, che contenga 3 coppie chiave-valore:
#   - "arancia", 2
#   - "mela", 5
#   - "banana", 1
# - Aggiungi una nuova coppia chiave-valore al dizionario: "pera", 3
# - Rimuovi le mele dal dizionario
# - Stampa il dizionario

# %% [markdown]
# #**Esercizio 3: Tuple**
#
# - Converti il dizionario fruits_dict in una tupla di tuple chiamata fruits_tuple
# - Ordina la Tupla in base al numero di frutti disponibili
# - stampa il frutto disponibile in minore quantità e in maggiore quantità;
#   - **risultato atteso**:
#
#     Frutto in quantità minore: banana 1
#
#     Frutto in quantità maggiore: mela 5
